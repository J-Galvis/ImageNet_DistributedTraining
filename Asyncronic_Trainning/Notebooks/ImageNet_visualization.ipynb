# %% [markdown]
# # ImageNet Neural Network Training Visualization

# %% [markdown]
# ### Import the graph module from Utils

# %%
import json
import sys
import os
from pathlib import Path
from typing import Optional

import altair as alt
import pandas as pd

# Añadir el directorio padre al path para acceder al paquete Utils
notebook_dir = os.path.dirname(os.path.abspath('../../__file__'))
sys.path.insert(0, os.path.abspath(notebook_dir))

# Importar funciones del dataset y utilidades desde el paquete Utils
from Utils.ComparationGraphs import (
    compare_runs, 
    load_from_paths, 
    load_training_folder, 
    runs_metadata,
    compare_speedups,
    speedups_to_dataframe
)

# %% [markdown]
# ### Define functions for comparassion

# %%
def main(folder: str = "../stats/ImagetNet"):

    runs = load_training_folder(folder)  

    print(runs_metadata(runs).to_string())

    chart = compare_runs(runs, loose=True)
    chart.display()
    return 0

def speedup_analysis(folder: str = "../stats/ImagetNet", base_case: str = None):

    runs = load_training_folder(folder)
    
    # Display metadata
    print(f"Speedup comparison (baseline: '{base_case}'):")
    print(runs_metadata(runs).to_string())
    
    # Create speedup visualization
    chart = compare_speedups(runs, base_case=base_case)
    chart.display()
    
    return runs

# %% [markdown]
# ### Physical Testing
#
# <img src="../Images/ImageNet/Ryzen.png">
# <img src="../Images/ImageNet/I912.png">

# %%
main("../stats")
# Out:
#   ✔  Loaded '4WorkersSin'  ←  4WorkersSin_metadata.json
#   ✔  Loaded 'Async'  ←  Async_metadata.json
#
# 2 run(s) loaded from '/home/walviz/Documents/Personal files/Universidad/Semestre 10/ClienteServidor/ImageNet/Asyncronic_Trainning/stats'.
#
#              test_acc (%)  epochs  learning_rate  train_time (s) arch_hidden num_partitions                                architecture
# model
# 4WorkersSin           0.0      30         0.0001    43071.762927        None           None  ImageNet ResNet - Distributed with Sockets
# Async                 0.0      30         0.0001    16383.366404        None           None    ImageNet ResNet - Async-SGD with Sockets
# [DEBUG] 4WorkersSin (epoch-level) → epoch=30, time=30, acc=30, loss=30
# [DEBUG] Async (epoch-level) → epoch=30, time=30, acc=30, loss=30
# [DEBUG] Final dataframe shape: (60, 5) (granularity=epoch)
# alt.VConcatChart(...)
# 0

# %% [markdown]
# ## Speed up Comparassion

# %%
speedup_analysis("../stats", base_case="4WorkersSinz`")
# Out:
#   ✔  Loaded '4WorkersSin'  ←  4WorkersSin_metadata.json
#   ✔  Loaded 'Async'  ←  Async_metadata.json
#
# 2 run(s) loaded from '/home/walviz/Documents/Personal files/Universidad/Semestre 10/ClienteServidor/ImageNet/Asyncronic_Trainning/stats'.
#
# Speedup comparison (baseline: '4WorkersSinz`'):
#              test_acc (%)  epochs  learning_rate  train_time (s) arch_hidden num_partitions                                architecture
# model
# 4WorkersSin           0.0      30         0.0001    43071.762927        None           None  ImageNet ResNet - Distributed with Sockets
# Async                 0.0      30         0.0001    16383.366404        None           None    ImageNet ResNet - Async-SGD with Sockets
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 speedup_analysis("../stats", base_case="4WorkersSinz`")
#
# Cell In[14], line 20, in speedup_analysis(folder, base_case)
#      16     print(f"Speedup comparison (baseline: '{base_case}'):")
#      17     print(runs_metadata(runs).to_string())
#      18
#      19     # Create speedup visualization
# ---> 20     chart = compare_speedups(runs, base_case=base_case)
#      21     chart.display()
#      22
#      23     return runs
#
# File ~/Documents/Personal files/Universidad/Semestre 10/ClienteServidor/ImageNet/Utils/ComparationGraphs.py:639, in compare_speedups(runs, base_case, keys, save_html, granularity)
#     606 """
#     607 Create a speedup comparison visualization relative to a baseline implementation.
#     608
#    (...)    636     If base_case has no training time data.
#     637 """
#     638 # Normalize base_case to handle both model names and file paths
# --> 639 base_case = _normalize_base_case(base_case, runs)
#     641 # ── select subset ────────────────────────────────────────────────────────
#     642 if keys:
#
# File ~/Documents/Personal files/Universidad/Semestre 10/ClienteServidor/ImageNet/Utils/ComparationGraphs.py:486, in _normalize_base_case(base_case, runs)
#     483     return extracted
#     485 # Not found in either format
# --> 486 raise KeyError(
#     487     f"Base case '{base_case}' not found. "
#     488     f"Available models: {list(runs.keys())}"
#     489 )
#
# KeyError: "Base case '4WorkersSinz`' not found. Available models: ['4WorkersSin', 'Async']"
